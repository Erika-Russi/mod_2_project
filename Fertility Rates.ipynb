# %%
import pandas as pd
import csv
fertility=pd.read_csv('Fertility.csv')
fertility.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1  Afghanistan          AFG  Fertility rate, total (births per woman)
# 2       Angola          AGO  Fertility rate, total (births per woman)
# 3      Albania          ALB  Fertility rate, total (births per woman)
# 4      Andorra          AND  Fertility rate, total (births per woman)
#
#    Indicator Code   1960   1961   1962   1963   1964   1965     ...       \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842     ...
# 1  SP.DYN.TFRT.IN  7.450  7.450  7.450  7.450  7.450  7.450     ...
# 2  SP.DYN.TFRT.IN  7.478  7.524  7.563  7.592  7.611  7.619     ...
# 3  SP.DYN.TFRT.IN  6.489  6.401  6.282  6.133  5.960  5.773     ...
# 4  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN     ...
#
#     2009   2010   2011   2012   2013   2014   2015   2016  2017  Unnamed: 62
# ...

# %%
density=pd.read_csv('Density.csv')
density
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
# frames = [density, fertility] 
density_vs_fertility = density.merge(fertility, on='Country Name', how='left')
density_vs_fertility
# Out:
#                                           Country Name Country Code_x  \
# 0                                                Aruba            ABW
# 1                                          Afghanistan            AFG
# 2                                               Angola            AGO
# 3                                              Albania            ALB
# 4                                              Andorra            AND
# 5                                           Arab World            ARB
# 6                                 United Arab Emirates            ARE
# 7                                            Argentina            ARG
# 8                                              Armenia            ARM
# 9                                       American Samoa            ASM
# 10                                 Antigua and Barbuda            ATG
# 11                                           Australia            AUS
# ...

# %%
density_vs_fertility = density_vs_fertility.dropna(subset = ['2016_x'])

# %%
density_vs_fertility = density_vs_fertility.dropna(subset = ['2016_y'])

# %%
density_vs_fertility
# Out:
#                                           Country Name Country Code_x  \
# 0                                                Aruba            ABW
# 1                                          Afghanistan            AFG
# 2                                               Angola            AGO
# 3                                              Albania            ALB
# 5                                           Arab World            ARB
# 6                                 United Arab Emirates            ARE
# 7                                            Argentina            ARG
# 8                                              Armenia            ARM
# 10                                 Antigua and Barbuda            ATG
# 11                                           Australia            AUS
# 12                                             Austria            AUT
# 13                                          Azerbaijan            AZE
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# plt.rcParams['figure.figsize'] = (8, 6)
# plt.rcParams['font.size'] = 14

# %%
# Pandas scatter plot
plt.scatter(density_vs_fertility['2016_x'], density_vs_fertility['2016_y'])
# density_vs_fertility.plot(kind='scatter', x='2016_x', y='2016_y', alpha=0.2)

# %%
#outliers above are ruining visibility
dvf = density_vs_fertility[density_vs_fertility.loc[:,'2016_x'] < 1000]

# %%
# Out:
#                                           Country Name Country Code_x  \
# 0                                                Aruba            ABW
# 1                                          Afghanistan            AFG
# 2                                               Angola            AGO
# 3                                              Albania            ALB
# 5                                           Arab World            ARB
# 6                                 United Arab Emirates            ARE
# 7                                            Argentina            ARG
# 8                                              Armenia            ARM
# 10                                 Antigua and Barbuda            ATG
# 11                                           Australia            AUS
# 12                                             Austria            AUT
# 13                                          Azerbaijan            AZE
# ...

# %%
plt.scatter(dvf['2016_x'], dvf['2016_y'])

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
dvf.plot(kind='scatter', x='2016_x', y='2016_y', alpha=0.2)

# %%
#without outliers
sns.lmplot(x='2016_x', y='2016_y', data = dvf, aspect= 1.5, scatter_kws={'alpha':0.05})
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#with outliers
sns.lmplot(x='2016_x', y='2016_y', data = density_vs_fertility, aspect= 1.5, scatter_kws={'alpha':0.05})
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
